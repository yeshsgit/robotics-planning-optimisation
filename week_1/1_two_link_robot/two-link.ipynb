# %%
import numpy as np

# %%
def fk(l_1, l_2, theta_1, theta_2) -> tuple[int, int]:
    """
    
    """
    
    x = l_1 * np.cos(theta_1) + l_2 * np.cos(theta_1 + theta_2)
    y = l_1 * np.sin(theta_1) + l_2 * np.sin(theta_1 + theta_2)
    
    return (x, y)

# %%
def ik(l_1, l_2, x, y) -> tuple[int, int]:
    """
    
    """

    pass
